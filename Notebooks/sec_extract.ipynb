# %%
import pandas
import os
import zipfile
from os import path
from os.path import join
import shutil

# %%
os.chdir("..")

dir_root = os.getcwd()

print(dir_root)
# Out:
# /home/wc/Azimuth/Trader

# %%
dir_name = dir_root + u"/sec_filings/Filings"

dir_raw = dir_root + u"/sec_filings/Raw"

for root, dirs, files in os.walk(dir_name):
    directory_name = os.path.split(root)[1]
    for fname in files:
        newname = directory_name + "_" + fname
        print(join(dir_raw,newname))
        shutil.copy(join(root,fname), join(dir_raw,newname))
#         os.rename(join(root,name),join(root,newname))
# Out:
# /home/wc/Azimuth/Trader/sec_filings/Raw/2018q3_pre.txt
# /home/wc/Azimuth/Trader/sec_filings/Raw/2018q3_num.txt
# /home/wc/Azimuth/Trader/sec_filings/Raw/2018q3_readme.htm
# /home/wc/Azimuth/Trader/sec_filings/Raw/2018q3_sub.txt
# /home/wc/Azimuth/Trader/sec_filings/Raw/2018q3_tag.txt
# /home/wc/Azimuth/Trader/sec_filings/Raw/2017q3_pre.txt
# /home/wc/Azimuth/Trader/sec_filings/Raw/2017q3_num.txt
# /home/wc/Azimuth/Trader/sec_filings/Raw/2017q3_readme.htm
# /home/wc/Azimuth/Trader/sec_filings/Raw/2017q3_sub.txt
# /home/wc/Azimuth/Trader/sec_filings/Raw/2017q3_tag.txt
# /home/wc/Azimuth/Trader/sec_filings/Raw/2017q1_pre.txt
# /home/wc/Azimuth/Trader/sec_filings/Raw/2017q1_num.txt
# /home/wc/Azimuth/Trader/sec_filings/Raw/2017q1_readme.htm
# /home/wc/Azimuth/Trader/sec_filings/Raw/2017q1_sub.txt
# /home/wc/Azimuth/Trader/sec_filings/Raw/2017q1_tag.txt
# /home/wc/Azimuth/Trader/sec_filings/Raw/2009q2_pre.txt
# /home/wc/Azimuth/Trader/sec_filings/Raw/2009q2_num.txt
# /home/wc/Azimuth/Trader/sec_filings/Raw/2009q2_readme.htm
# /home/wc/Azimuth/Trader/sec_filings/Raw/2009q2_sub.txt
# /home/wc/Azimuth/Trader/sec_filings/Raw/2009q2_tag.txt
# /home/wc/Azimuth/Trader/sec_filings/Raw/2018q4_pre.txt
# /home/wc/Azimuth/Trader/sec_filings/Raw/2018q4_num.txt
# /home/wc/Azimuth/Trader/sec_filings/Raw/2018q4_readme.htm
# /home/wc/Azimuth/Trader/sec_filings/Raw/2018q4_sub.txt
# /home/wc/Azimuth/Trader/sec_filings/Raw/2018q4_tag.txt
# /home/wc/Azimuth/Trader/sec_filings/Raw/2011q3_pre.txt
# /home/wc/Azimuth/Trader/sec_filings/Raw/2011q3_num.txt
# /home/wc/Azimuth/Trader/sec_filings/Raw/2011q3_readme.htm
# /home/wc/Azimuth/Trader/sec_filings/Raw/2011q3_sub.txt
# /home/wc/Azimuth/Trader/sec_filings/Raw/2011q3_tag.txt
# /home/wc/Azimuth/Trader/sec_filings/Raw/2009q4_pre.txt
# /home/wc/Azimuth/Trader/sec_filings/Raw/2009q4_num.txt
# /home/wc/Azimuth/Trader/sec_filings/Raw/2009q4_readme.htm
# /home/wc/Azimuth/Trader/sec_filings/Raw/2009q4_sub.txt
# /home/wc/Azimuth/Trader/sec_filings/Raw/2009q4_tag.txt
# /home/wc/Azimuth/Trader/sec_filings/Raw/2019q3_pre.txt
# /home/wc/Azimuth/Trader/sec_filings/Raw/2019q3_num.txt
# /home/wc/Azimuth/Trader/sec_filings/Raw/2019q3_readme.htm
# /home/wc/Azimuth/Trader/sec_filings/Raw/2019q3_sub.txt
# /home/wc/Azimuth/Trader/sec_filings/Raw/2019q3_tag.txt
# /home/wc/Azimuth/Trader/sec_filings/Raw/2012q3_pre.txt
# /home/wc/Azimuth/Trader/sec_filings/Raw/2012q3_num.txt
# /home/wc/Azimuth/Trader/sec_filings/Raw/2012q3_readme.htm
# /home/wc/Azimuth/Trader/sec_filings/Raw/2012q3_sub.txt
# /home/wc/Azimuth/Trader/sec_filings/Raw/2012q3_tag.txt
# /home/wc/Azimuth/Trader/sec_filings/Raw/2015q3_pre.txt
# /home/wc/Azimuth/Trader/sec_filings/Raw/2015q3_num.txt
# /home/wc/Azimuth/Trader/sec_filings/Raw/2015q3_readme.htm
# /home/wc/Azimuth/Trader/sec_filings/Raw/2015q3_sub.txt
# /home/wc/Azimuth/Trader/sec_filings/Raw/2015q3_tag.txt
# /home/wc/Azimuth/Trader/sec_filings/Raw/2016q2_pre.txt
# /home/wc/Azimuth/Trader/sec_filings/Raw/2016q2_num.txt
# /home/wc/Azimuth/Trader/sec_filings/Raw/2016q2_readme.htm
# /home/wc/Azimuth/Trader/sec_filings/Raw/2016q2_sub.txt
# /home/wc/Azimuth/Trader/sec_filings/Raw/2016q2_tag.txt
# /home/wc/Azimuth/Trader/sec_filings/Raw/2019q1_pre.txt
# /home/wc/Azimuth/Trader/sec_filings/Raw/2019q1_num.txt
# /home/wc/Azimuth/Trader/sec_filings/Raw/2019q1_readme.htm
# /home/wc/Azimuth/Trader/sec_filings/Raw/2019q1_sub.txt
# /home/wc/Azimuth/Trader/sec_filings/Raw/2019q1_tag.txt
# /home/wc/Azimuth/Trader/sec_filings/Raw/2019q2_pre.txt
# /home/wc/Azimuth/Trader/sec_filings/Raw/2019q2_num.txt
# /home/wc/Azimuth/Trader/sec_filings/Raw/2019q2_readme.htm
# /home/wc/Azimuth/Trader/sec_filings/Raw/2019q2_sub.txt
# /home/wc/Azimuth/Trader/sec_filings/Raw/2019q2_tag.txt
# /home/wc/Azimuth/Trader/sec_filings/Raw/2014q1_pre.txt
# /home/wc/Azimuth/Trader/sec_filings/Raw/2014q1_num.txt
# /home/wc/Azimuth/Trader/sec_filings/Raw/2014q1_readme.htm
# /home/wc/Azimuth/Trader/sec_filings/Raw/2014q1_sub.txt
# /home/wc/Azimuth/Trader/sec_filings/Raw/2014q1_tag.txt
# /home/wc/Azimuth/Trader/sec_filings/Raw/2014q2_pre.txt
# /home/wc/Azimuth/Trader/sec_filings/Raw/2014q2_num.txt
# /home/wc/Azimuth/Trader/sec_filings/Raw/2014q2_readme.htm
# /home/wc/Azimuth/Trader/sec_filings/Raw/2014q2_sub.txt
# /home/wc/Azimuth/Trader/sec_filings/Raw/2014q2_tag.txt
# /home/wc/Azimuth/Trader/sec_filings/Raw/2012q4_pre.txt
# /home/wc/Azimuth/Trader/sec_filings/Raw/2012q4_num.txt
# /home/wc/Azimuth/Trader/sec_filings/Raw/2012q4_readme.htm
# /home/wc/Azimuth/Trader/sec_filings/Raw/2012q4_sub.txt
# /home/wc/Azimuth/Trader/sec_filings/Raw/2012q4_tag.txt
# /home/wc/Azimuth/Trader/sec_filings/Raw/2009q3_pre.txt
# /home/wc/Azimuth/Trader/sec_filings/Raw/2009q3_num.txt
# /home/wc/Azimuth/Trader/sec_filings/Raw/2009q3_readme.htm
# /home/wc/Azimuth/Trader/sec_filings/Raw/2009q3_sub.txt
# /home/wc/Azimuth/Trader/sec_filings/Raw/2009q3_tag.txt
# /home/wc/Azimuth/Trader/sec_filings/Raw/2015q2_pre.txt
# /home/wc/Azimuth/Trader/sec_filings/Raw/2015q2_num.txt
# /home/wc/Azimuth/Trader/sec_filings/Raw/2015q2_readme.htm
# /home/wc/Azimuth/Trader/sec_filings/Raw/2015q2_sub.txt
# /home/wc/Azimuth/Trader/sec_filings/Raw/2015q2_tag.txt
# /home/wc/Azimuth/Trader/sec_filings/Raw/2013q3_pre.txt
# /home/wc/Azimuth/Trader/sec_filings/Raw/2013q3_num.txt
# /home/wc/Azimuth/Trader/sec_filings/Raw/2013q3_readme.htm
# /home/wc/Azimuth/Trader/sec_filings/Raw/2013q3_sub.txt
# /home/wc/Azimuth/Trader/sec_filings/Raw/2013q3_tag.txt
# /home/wc/Azimuth/Trader/sec_filings/Raw/2016q1_pre.txt
# /home/wc/Azimuth/Trader/sec_filings/Raw/2016q1_num.txt
# /home/wc/Azimuth/Trader/sec_filings/Raw/2016q1_readme.htm
# /home/wc/Azimuth/Trader/sec_filings/Raw/2016q1_sub.txt
# /home/wc/Azimuth/Trader/sec_filings/Raw/2016q1_tag.txt
# /home/wc/Azimuth/Trader/sec_filings/Raw/2010q3_pre.txt
# /home/wc/Azimuth/Trader/sec_filings/Raw/2010q3_num.txt
# /home/wc/Azimuth/Trader/sec_filings/Raw/2010q3_readme.htm
# /home/wc/Azimuth/Trader/sec_filings/Raw/2010q3_sub.txt
# /home/wc/Azimuth/Trader/sec_filings/Raw/2010q3_tag.txt
# /home/wc/Azimuth/Trader/sec_filings/Raw/2014q3_pre.txt
# /home/wc/Azimuth/Trader/sec_filings/Raw/2014q3_num.txt
# /home/wc/Azimuth/Trader/sec_filings/Raw/2014q3_readme.htm
# /home/wc/Azimuth/Trader/sec_filings/Raw/2014q3_sub.txt
# /home/wc/Azimuth/Trader/sec_filings/Raw/2014q3_tag.txt
# /home/wc/Azimuth/Trader/sec_filings/Raw/2015q1_pre.txt
# /home/wc/Azimuth/Trader/sec_filings/Raw/2015q1_num.txt
# /home/wc/Azimuth/Trader/sec_filings/Raw/2015q1_readme.htm
# /home/wc/Azimuth/Trader/sec_filings/Raw/2015q1_sub.txt
# /home/wc/Azimuth/Trader/sec_filings/Raw/2015q1_tag.txt
# /home/wc/Azimuth/Trader/sec_filings/Raw/2014q4_pre.txt
# /home/wc/Azimuth/Trader/sec_filings/Raw/2014q4_num.txt
# /home/wc/Azimuth/Trader/sec_filings/Raw/2014q4_readme.htm
# /home/wc/Azimuth/Trader/sec_filings/Raw/2014q4_sub.txt
# /home/wc/Azimuth/Trader/sec_filings/Raw/2014q4_tag.txt
# /home/wc/Azimuth/Trader/sec_filings/Raw/2015q4_pre.txt
# /home/wc/Azimuth/Trader/sec_filings/Raw/2015q4_num.txt
# /home/wc/Azimuth/Trader/sec_filings/Raw/2015q4_readme.htm
# /home/wc/Azimuth/Trader/sec_filings/Raw/2015q4_sub.txt
# /home/wc/Azimuth/Trader/sec_filings/Raw/2015q4_tag.txt
# /home/wc/Azimuth/Trader/sec_filings/Raw/2017q4_pre.txt
# /home/wc/Azimuth/Trader/sec_filings/Raw/2017q4_num.txt
# /home/wc/Azimuth/Trader/sec_filings/Raw/2017q4_readme.htm
# /home/wc/Azimuth/Trader/sec_filings/Raw/2017q4_sub.txt
# /home/wc/Azimuth/Trader/sec_filings/Raw/2017q4_tag.txt
# /home/wc/Azimuth/Trader/sec_filings/Raw/2018q1_pre.txt
# /home/wc/Azimuth/Trader/sec_filings/Raw/2018q1_num.txt
# /home/wc/Azimuth/Trader/sec_filings/Raw/2018q1_readme.htm
# /home/wc/Azimuth/Trader/sec_filings/Raw/2018q1_sub.txt
# /home/wc/Azimuth/Trader/sec_filings/Raw/2018q1_tag.txt
# /home/wc/Azimuth/Trader/sec_filings/Raw/2010q2_pre.txt
# /home/wc/Azimuth/Trader/sec_filings/Raw/2010q2_num.txt
# /home/wc/Azimuth/Trader/sec_filings/Raw/2010q2_readme.htm
# /home/wc/Azimuth/Trader/sec_filings/Raw/2010q2_sub.txt
# /home/wc/Azimuth/Trader/sec_filings/Raw/2010q2_tag.txt
# /home/wc/Azimuth/Trader/sec_filings/Raw/2013q1_pre.txt
# /home/wc/Azimuth/Trader/sec_filings/Raw/2013q1_num.txt
# /home/wc/Azimuth/Trader/sec_filings/Raw/2013q1_readme.htm
# /home/wc/Azimuth/Trader/sec_filings/Raw/2013q1_sub.txt
# /home/wc/Azimuth/Trader/sec_filings/Raw/2013q1_tag.txt
# /home/wc/Azimuth/Trader/sec_filings/Raw/2017q2_pre.txt
# /home/wc/Azimuth/Trader/sec_filings/Raw/2017q2_num.txt
# /home/wc/Azimuth/Trader/sec_filings/Raw/2017q2_readme.htm
# /home/wc/Azimuth/Trader/sec_filings/Raw/2017q2_sub.txt
# /home/wc/Azimuth/Trader/sec_filings/Raw/2017q2_tag.txt
# /home/wc/Azimuth/Trader/sec_filings/Raw/2016q3_pre.txt
# /home/wc/Azimuth/Trader/sec_filings/Raw/2016q3_num.txt
# /home/wc/Azimuth/Trader/sec_filings/Raw/2016q3_readme.htm
# /home/wc/Azimuth/Trader/sec_filings/Raw/2016q3_sub.txt
# /home/wc/Azimuth/Trader/sec_filings/Raw/2016q3_tag.txt
# /home/wc/Azimuth/Trader/sec_filings/Raw/2013q2_pre.txt
# /home/wc/Azimuth/Trader/sec_filings/Raw/2013q2_num.txt
# /home/wc/Azimuth/Trader/sec_filings/Raw/2013q2_readme.htm
# /home/wc/Azimuth/Trader/sec_filings/Raw/2013q2_sub.txt
# /home/wc/Azimuth/Trader/sec_filings/Raw/2013q2_tag.txt
# /home/wc/Azimuth/Trader/sec_filings/Raw/2011q2_pre.txt
# /home/wc/Azimuth/Trader/sec_filings/Raw/2011q2_num.txt
# /home/wc/Azimuth/Trader/sec_filings/Raw/2011q2_readme.htm
# /home/wc/Azimuth/Trader/sec_filings/Raw/2011q2_sub.txt
# /home/wc/Azimuth/Trader/sec_filings/Raw/2011q2_tag.txt
# /home/wc/Azimuth/Trader/sec_filings/Raw/2010q1_pre.txt
# /home/wc/Azimuth/Trader/sec_filings/Raw/2010q1_num.txt
# /home/wc/Azimuth/Trader/sec_filings/Raw/2010q1_readme.htm
# /home/wc/Azimuth/Trader/sec_filings/Raw/2010q1_sub.txt
# /home/wc/Azimuth/Trader/sec_filings/Raw/2010q1_tag.txt
# /home/wc/Azimuth/Trader/sec_filings/Raw/2016q4_pre.txt
# /home/wc/Azimuth/Trader/sec_filings/Raw/2016q4_num.txt
# /home/wc/Azimuth/Trader/sec_filings/Raw/2016q4_readme.htm
# /home/wc/Azimuth/Trader/sec_filings/Raw/2016q4_sub.txt
# /home/wc/Azimuth/Trader/sec_filings/Raw/2016q4_tag.txt
# /home/wc/Azimuth/Trader/sec_filings/Raw/2013q4_pre.txt
# /home/wc/Azimuth/Trader/sec_filings/Raw/2013q4_num.txt
# /home/wc/Azimuth/Trader/sec_filings/Raw/2013q4_readme.htm
# /home/wc/Azimuth/Trader/sec_filings/Raw/2013q4_sub.txt
# /home/wc/Azimuth/Trader/sec_filings/Raw/2013q4_tag.txt
# /home/wc/Azimuth/Trader/sec_filings/Raw/2010q4_pre.txt
# /home/wc/Azimuth/Trader/sec_filings/Raw/2010q4_num.txt
# /home/wc/Azimuth/Trader/sec_filings/Raw/2010q4_readme.htm
# /home/wc/Azimuth/Trader/sec_filings/Raw/2010q4_sub.txt
# /home/wc/Azimuth/Trader/sec_filings/Raw/2010q4_tag.txt
# /home/wc/Azimuth/Trader/sec_filings/Raw/2009q1_pre.txt
# /home/wc/Azimuth/Trader/sec_filings/Raw/2009q1_num.txt
# /home/wc/Azimuth/Trader/sec_filings/Raw/2009q1_readme.htm
# /home/wc/Azimuth/Trader/sec_filings/Raw/2009q1_sub.txt
# /home/wc/Azimuth/Trader/sec_filings/Raw/2009q1_tag.txt
# /home/wc/Azimuth/Trader/sec_filings/Raw/2019q4_pre.txt
# /home/wc/Azimuth/Trader/sec_filings/Raw/2019q4_num.txt
# /home/wc/Azimuth/Trader/sec_filings/Raw/2019q4_readme.htm
# /home/wc/Azimuth/Trader/sec_filings/Raw/2019q4_sub.txt
# /home/wc/Azimuth/Trader/sec_filings/Raw/2019q4_tag.txt
# /home/wc/Azimuth/Trader/sec_filings/Raw/2012q1_pre.txt
# /home/wc/Azimuth/Trader/sec_filings/Raw/2012q1_num.txt
# /home/wc/Azimuth/Trader/sec_filings/Raw/2012q1_readme.htm
# /home/wc/Azimuth/Trader/sec_filings/Raw/2012q1_sub.txt
# /home/wc/Azimuth/Trader/sec_filings/Raw/2012q1_tag.txt
# /home/wc/Azimuth/Trader/sec_filings/Raw/2011q1_pre.txt
# /home/wc/Azimuth/Trader/sec_filings/Raw/2011q1_num.txt
# /home/wc/Azimuth/Trader/sec_filings/Raw/2011q1_readme.htm
# /home/wc/Azimuth/Trader/sec_filings/Raw/2011q1_sub.txt
# /home/wc/Azimuth/Trader/sec_filings/Raw/2011q1_tag.txt
# /home/wc/Azimuth/Trader/sec_filings/Raw/2012q2_pre.txt
# /home/wc/Azimuth/Trader/sec_filings/Raw/2012q2_num.txt
# /home/wc/Azimuth/Trader/sec_filings/Raw/2012q2_readme.htm
# /home/wc/Azimuth/Trader/sec_filings/Raw/2012q2_sub.txt
# /home/wc/Azimuth/Trader/sec_filings/Raw/2012q2_tag.txt
# /home/wc/Azimuth/Trader/sec_filings/Raw/2018q2_pre.txt
# /home/wc/Azimuth/Trader/sec_filings/Raw/2018q2_num.txt
# /home/wc/Azimuth/Trader/sec_filings/Raw/2018q2_readme.htm
# /home/wc/Azimuth/Trader/sec_filings/Raw/2018q2_sub.txt
# /home/wc/Azimuth/Trader/sec_filings/Raw/2018q2_tag.txt
# /home/wc/Azimuth/Trader/sec_filings/Raw/2011q4_pre.txt
# /home/wc/Azimuth/Trader/sec_filings/Raw/2011q4_num.txt
# /home/wc/Azimuth/Trader/sec_filings/Raw/2011q4_readme.htm
# /home/wc/Azimuth/Trader/sec_filings/Raw/2011q4_sub.txt
# /home/wc/Azimuth/Trader/sec_filings/Raw/2011q4_tag.txt
